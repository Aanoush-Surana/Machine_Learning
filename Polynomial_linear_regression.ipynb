# %% [markdown]
# <a href="https://colab.research.google.com/github/Aanoush-Surana/Machine_Learning/blob/main/Polynomial_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# IMPORTING DATASET

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[: , 1:-1].values
y = dataset.iloc[: , -1].values

# %% [markdown]
# TRAINING LINEAR REGRESSION MODEL (ON WHOLE DATA)

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()
le.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# TRAINING POLYNOMIAL REGRESSION MODEL (ON WHOLE DATA)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly , y )
# Out:
# LinearRegression()

# %% [markdown]
# VISUALISING LINEAR REGRESSION

# %%
plt.scatter(X,y , color='red')
plt.plot(X,le.predict(X) , color = 'blue')
plt.title('TRUTH OR BLUFF (LINEAR REGRESSION)')
plt.xlabel('LEVEL')
plt.ylabel('SALARY')
plt.show()

# %% [markdown]
# VISUALISING THE POLYNOMIAL REGRESSION

# %%
plt.scatter(X , y , color='red')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)) , color = 'blue')
plt.title('TRUTH OR BLUFF (POLYNOMIAL REGRESSION)')
plt.xlabel('LEVEL')
plt.ylabel('SALARY')
plt.show()

# %% [markdown]
# PREDICTION USING LINEAR MODEL

# %%
le.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# PREDICTION USING POLYNOMIAL MODEL

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
